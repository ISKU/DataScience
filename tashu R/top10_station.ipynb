# %%
library(ggplot2)
tashu <- read.csv('tashu.csv', header = TRUE)

# %%
top_rent <- data.frame(table(tashu $ RENT_STATION))
top_return <- data.frame(table(tashu $ RETURN_STATION))

# %%
merged <- merge(top_rent, top_return, by = 'Var1')
merged
# Out:
#     Var1 Freq.x Freq.y
# 1   1    49886  49773
# 2   10   38894  38859
# 3   100   7480   7514
# 4   101   4760   4737
# 5   102   4247   4258
# 6   103   4147   4121
# 7   104  10824  10757
# 8   105  56306  56740
# 9   106  35986  35614
# 10  107  26886  26695
# 11  108  48065  47978
# 12  109  26591  26559
# 13  11   25921  25854
# 14  110  33186  33231
# 15  111  18675  18681
# 16  112  24358  24446
# 17  113  12521  12526
# 18  114   4651   4651
# 19  115   6732   6694
# 20  116   8404   8322
# 21  117  13569  13561
# 22  118  14165  14074
# 23  119   3299   3261
# 24  12   45584  45097
# 25  120   4859   4874
# 26  121   4609   4622
# 27  122  34524  34699
# 28  123   2771   2766
# 29  124   5422   5406
# 30  125   6017   6028
# ⋮   ⋮    ⋮      ⋮
# 173 72    6632   6604
# 174 73    6682   6684
# 175 74   11104  10982
# 176 75    4920   4915
# 177 76    7758   7625
# 178 77    6235   6190
# 179 78    8753   8710
# 180 79    9246   9320
# 181 8    52471  52313
# 182 80    6449   6382
# 183 81   13550  13480
# 184 82    9092   8939
# 185 83   14242  14229
# 186 84   10652  10601
# 187 85    8978   9027
# 188 86   11264  11243
# 189 87   13812  13825
# 190 88    6515   6465
# 191 89   13306  13304
# 192 9    21205  21171
# 193 90   26423  26433
# 194 91    7528   7513
# 195 92    7225   7211
# 196 93    9450   9461
# 197 94    5990   5983
# 198 95   11787  11778
# 199 96    6317   6256
# 200 97    7901   7816
# 201 98    8670   8675
# 202 99    6199   6174

# %%
top_station <- data.frame(station = c(merged $ Var1), count = c(merged $ Freq.x + merged $ Freq.y))
top_station <- top_station[order(top_station $ count, decreasing = T),]
top_station[1:10,]
# Out:
#     station count
# 126   3     349549
# 155  56     182347
# 128  31     167060
# 79   17     166055
# 129  32     147279
# 130  33     142510
# 46   14     115049
# 8   105     113046
# 117  21     111935
# 154  55     110199

# %%
top_station $ station <- as.factor(top_station $ station)
top_station $ count <- as.factor(top_station $ count)
ggplot(top_station[1:10,], aes(station, count)) + geom_bar(stat = 'identity')
# Out:
# plot without title
